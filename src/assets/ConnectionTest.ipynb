# %%
%addconnect name=lake, user=de110922, host=100.127.255.74
# Out:
# Success: 'lake' connection added

# %%
%connect lake
# Out:
# Success: 'lake' connection established and activated for user 'de110922'

# %%
select databasename from dbc.databases where databasename like 'demo%' order by 1

# %%
select this is junk

# %%
select date
